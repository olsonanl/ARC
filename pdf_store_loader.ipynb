# %%
# pip install langchain chromadb
# What we want is an environment for procesing pdfs and loading them
# into a local vector store. We want a vector store that is fast. We
# want to process the pdfs into smart chunks. Finally, an outstanding
# question is how the pdf is represented in the vector store. More to 
# come on that.

# %%
from langchain.document_loaders import PyPDFLoader
from os import listdir
from os.path import isfile, join
import datetime
import time
from langchain.vectorstores import FAISS
from langchain.embeddings.openai import OpenAIEmbeddings

def _print(txt="HERE", last_time=time.time()):
    this_time = time.time()
    print("{}\t{}\t{}".format(datetime.datetime.now(),
                              this_time-last_time,
                              txt)
         )
    return time.time()

t = _print("Start.")


mypath="pdfs"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
print(f'file_count: {len(onlyfiles)}')

# This needs to run parallel
t = _print("Loading documents", t)
page_count = 0
pages = []
for pdf in onlyfiles:
    if pdf.endswith(".pdf"):
        loader = PyPDFLoader("pdfs/" + pdf)
        pages = loader.load_and_split()
        page_count = page_count + len(pages)
        
        # print(f"loading {pdf}")
        # print(f'page_count: {page_count}')
        
        # Need to get the falcon embeddings and embed these new pages

        # Then should investigate the best way to embed. How big of chunks.

        # Then need to load into a vector store
        
t = _print("Done loading documents", t)
# Out:
# 2023-12-11 21:39:07.893468	2.0742416381835938e-05	Start.
# file_count: 316
# 2023-12-11 21:39:07.940644	0.04710674285888672	Loading documents
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 38
#      32 page_count = page_count + len(pages)
#      34 # print(f"loading {pdf}")
#      35 # print(f'page_count: {page_count}')
#      36
#      37 # Need to get the falcon embeddings and embed these new pages
# ---> 38 docs = ArxivLoader(query="Antibiotic design using deep learning", load_max_docs=10).load()
#      39 text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
#      40 splits = text_splitter.split_documents(docs)
#
# NameError: name 'ArxivLoader' is not defined

# %%
print(f'pages: {len(pages)}')
print(pages)
# Need to get the falcon embeddings and embed these new pages
# from transformers import AutoTokenizer, AutoModelForCausalLM
# model_id = "tiiuae/falcon-180B"
# tokenizer = AutoTokenizer.from_pretrained(model_id)

# Then should investigate the best way to embed. How big of chunks.
# Then need to load into a vector store
# Out:
# pages: 27
# ...

# %%
_print("Creating FAISS index")
faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
_print("Done creating FAISS index")

# docs = faiss_index.similarity_search("How will the community be engaged?", k=2)
# for doc in docs:
#     print(str(doc.metadata["page"]) + ":", doc.page_content[:300])
# Out:
# 2023-12-11 21:44:25.038267	317.14482069015503	Creating FAISS index
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 _print("Creating FAISS index")
# ----> 2 faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
#       3 _print("Done creating FAISS index")
#       5 # docs = faiss_index.similarity_search("How will the community be engaged?", k=2)
#       6 # for doc in docs:
#       7 #     print(str(doc.metadata["page"]) + ":", doc.page_content[:300])
#
# File /rbscratch/brettin/conda_envs/openai-rag-arxiv/lib/python3.11/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
# ...

# %%
_print("Creating Chroma vector store")
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())
_print("Done creating vector store")

# %% [markdown]
# System: Add an optional system prompt here
# User: This is the user input
# Falcon: This is what the model generates
# User: This might be a second turn input
# Falcon: and so on
